# %%
import os
import math
import random
import smtplib

# %%
digits = "0123456789"
OTP = ""

for i in range (6):
    OTP += digits[math.floor(random.random()*10)]

otp = OTP + " is your OTP"
message = otp

# %%
s = smtplib.SMTP('smtp.gmail.com', 587)
s.starttls()

emailid = input("Enter your email: ")
s.login("shaistakhan70154@gmail.com", "bqia ndkb xnkw hhdc")
s.sendmail('&&&&&&',emailid,message)

a = input("Enter your OTP >>: ")
if a == OTP:
    print("Verified")
else:
    print("Please Check your OTP again")
# Out:
# Enter your email: shaistakhan70154@gmail.com
# Enter your OTP >>: 817179
# Verified
